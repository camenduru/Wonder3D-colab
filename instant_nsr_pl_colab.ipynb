# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/Wonder3D-colab/blob/main/instant_nsr_pl_colab.ipynb)

# %%
# %cd /content
# !git clone https://huggingface.co/camenduru/Wonder3D-test
# !git clone -b dev https://github.com/camenduru/Wonder3D

# !pip install -q pytorch-lightning==1.9.5 omegaconf torch_efficient_distloss nerfacc==0.3.3 PyMCubes trimesh
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab/tinycudann-1.7-cp310-cp310-linux_x86_64.whl
# !git clone https://huggingface.co/camenduru/torch_extensions_0_3_3_colab /root/.cache/torch_extensions

# %%
# %cd /content/Wonder3D/instant-nsr-pl
# !python launch.py --config configs/neuralangelo-ortho-wmask.yaml --gpu 0 --train dataset.root_dir=/content/Wonder3D-test dataset.scene=owl
